# %%
import pandas as pd
import numpy as np
vixod = pd.read_excel('/content/drive/MyDrive/севералмаз/График выходов подразделение 1.xlsx')
dolzn = pd.read_excel('/content/drive/MyDrive/севералмаз/Перечень должностей, подлежащих обязательному обучению 1.xlsx')
graf = pd.read_excel('/content/drive/MyDrive/севералмаз/График прохождения ОТ и ПБ.xlsx')

#bd_modified = vixod.set_index('')

# %%
graf2 = pd.read_excel('/content/drive/MyDrive/севералмаз/график3.xlsx')

# %%
graf2.head()
# Out:
#           фио                       должность     значение  \
# 0  Фамилия 14               Начальник участка  явка/неявка
# 1         NaN                             NaN  ночные часы
# 2  Фамилия 48  Заместитель начальника участка  явка/неявка
# 3         NaN                             NaN  ночные часы
# 4  Фамилия 15                  Старший мастер  явка/неявка
#
#   2024-01-01 00:00:00  2024-01-02 00:00:00  2024-01-03 00:00:00  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                  11                 11.0                 11.0
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    2024-01-04 00:00:00  2024-01-05 00:00:00  2024-01-06 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
graf2
# Out:
#             фио                       должность     значение  \
# 0    Фамилия 14               Начальник участка  явка/неявка
# 1           NaN                             NaN  ночные часы
# 2    Фамилия 48  Заместитель начальника участка  явка/неявка
# 3           NaN                             NaN  ночные часы
# 4    Фамилия 15                  Старший мастер  явка/неявка
# ..          ...                             ...          ...
# 97          NaN                             NaN  ночные часы
# 98   Фамилия 13              Машинист конвейера  явка/неявка
# 99          NaN                             NaN  ночные часы
# 100  Фамилия 19       Машинист насосных устанок  явка/неявка
# 101         NaN                             NaN  ночные часы
#
#     2024-01-01 00:00:00  2024-01-02 00:00:00  2024-01-03 00:00:00  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# ...

# %%
graf2.loc[ 1, "фио"] = "Фамилия 14"
graf2
# Out:
#             фио                       должность     значение  \
# 0    Фамилия 14               Начальник участка  явка/неявка
# 1    Фамилия 14                             NaN  ночные часы
# 2    Фамилия 48  Заместитель начальника участка  явка/неявка
# 3           NaN                             NaN  ночные часы
# 4    Фамилия 15                  Старший мастер  явка/неявка
# ..          ...                             ...          ...
# 97          NaN                             NaN  ночные часы
# 98   Фамилия 13              Машинист конвейера  явка/неявка
# 99          NaN                             NaN  ночные часы
# 100  Фамилия 19       Машинист насосных устанок  явка/неявка
# 101         NaN                             NaN  ночные часы
#
#     2024-01-01 00:00:00  2024-01-02 00:00:00  2024-01-03 00:00:00  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# ...

# %%
for i in range(2,101,2):
  graf2.loc[ i+1, "фио"] = graf2.loc[ i, "фио"]
graf2.head(15)
# Out:
#            фио                       должность     значение  \
# 0   Фамилия 14               Начальник участка  явка/неявка
# 1   Фамилия 14                             NaN  ночные часы
# 2   Фамилия 48  Заместитель начальника участка  явка/неявка
# 3   Фамилия 48                             NaN  ночные часы
# 4   Фамилия 15                  Старший мастер  явка/неявка
# 5   Фамилия 15                             NaN  ночные часы
# 6   Фамилия 21                  Старший мастер  явка/неявка
# 7   Фамилия 21                             NaN  ночные часы
# 8   Фамилия 25                  Старший мастер  явка/неявка
# 9   Фамилия 25                             NaN  ночные часы
# 10  Фамилия 31                  Старший мастер  явка/неявка
# 11  Фамилия 31                             NaN  ночные часы
# 12  Фамилия 49                  Старший мастер  явка/неявка
# 13  Фамилия 49                             NaN  ночные часы
# 14  Фамилия 46                       Диспетчер  явка/неявка
#
# ...

# %%
for i in range(0,101,2):
  graf2.loc[ i+1, "должность"] = graf2.loc[ i, "должность"]
graf2
# Out:
#             фио                       должность     значение  \
# 0    Фамилия 14               Начальник участка  явка/неявка
# 1    Фамилия 14               Начальник участка  ночные часы
# 2    Фамилия 48  Заместитель начальника участка  явка/неявка
# 3    Фамилия 48  Заместитель начальника участка  ночные часы
# 4    Фамилия 15                  Старший мастер  явка/неявка
# ..          ...                             ...          ...
# 97   Фамилия 34                      Дробильщик  ночные часы
# 98   Фамилия 13              Машинист конвейера  явка/неявка
# 99   Фамилия 13              Машинист конвейера  ночные часы
# 100  Фамилия 19       Машинист насосных устанок  явка/неявка
# 101  Фамилия 19       Машинист насосных устанок  ночные часы
#
#     2024-01-01 00:00:00  2024-01-02 00:00:00  2024-01-03 00:00:00  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# ...

# %%
spisok_podrazd=pd.read_excel('/content/drive/MyDrive/севералмаз/шр подразд 1.xlsx')

# %%
spisok_podrazd = spisok_podrazd.drop(labels = [0], axis = 0)
spisok_podrazd['Фамилия'] = spisok_podrazd.iloc[:, 1]
spisok_podrazd['Должность'] = spisok_podrazd.iloc[:, 0]
spisok_podrazd = spisok_podrazd.drop(spisok_podrazd.columns[[0,1]], axis=1)
spisok_podrazd.head(10)
# Out:
#        Фамилия                    Должность
# 1    Фамилия 1                    Диспетчер
# 2    Фамилия 2                 Сепараторщик
# 3    Фамилия 3           Машинист конвейера
# 4    Фамилия 4             Машинист мельниц
# 5    Фамилия 5                 Сепараторщик
# 6    Фамилия 6                 Сепараторщик
# 7    Фамилия 7                 Сепараторщик
# 8    Фамилия 8             Машинист мельниц
# 9    Фамилия 9                 Сепараторщик
# 10  Фамилия 10  Машинист насосных установок

# %%
spisok_dolzn=pd.read_excel('/content/drive/MyDrive/севералмаз/лист должностей.xlsx')
spisok_dolzn
# Out:
#                                            Должность  id
# 0                                          Диспетчер   0
# 1                                       Сепараторщик   1
# 2                                  Начальник участка   2
# 3                                     Старший мастер   3
# 4                                   Машинист мельниц   4
# 5                     Заместитель начальника участка   5
# 6  Машинист установки по разрушению негабаритов г...   6
# 7                        Машинист насосных установок   7
# 8                                 Машинист конвейера   8
# 9                                         Дробильщик   9

# %%
result = pd.merge(spisok_podrazd, spisok_dolzn, on="Должность")
result.head()
# Out:
#      Фамилия           Должность  id
# 0  Фамилия 1           Диспетчер   0
# 1  Фамилия 2        Сепараторщик   1
# 2  Фамилия 3  Машинист конвейера   8
# 3  Фамилия 4    Машинист мельниц   4
# 4  Фамилия 5        Сепараторщик   1

# %%
result2=result.rename(columns = {'Фамилия':'фио'})
result2.head()
# Out:
#          фио           Должность  id
# 0  Фамилия 1           Диспетчер   0
# 1  Фамилия 2        Сепараторщик   1
# 2  Фамилия 3  Машинист конвейера   8
# 3  Фамилия 4    Машинист мельниц   4
# 4  Фамилия 5        Сепараторщик   1

# %%
graf3= pd.merge(graf2, result2, on="фио")
graf3.head(10)
# Out:
#           фио                       должность     значение  \
# 0  Фамилия 14               Начальник участка  явка/неявка
# 1  Фамилия 14               Начальник участка  ночные часы
# 2  Фамилия 48  Заместитель начальника участка  явка/неявка
# 3  Фамилия 48  Заместитель начальника участка  ночные часы
# 4  Фамилия 15                  Старший мастер  явка/неявка
# 5  Фамилия 15                  Старший мастер  ночные часы
# 6  Фамилия 21                  Старший мастер  явка/неявка
# 7  Фамилия 21                  Старший мастер  ночные часы
# 8  Фамилия 25                  Старший мастер  явка/неявка
# 9  Фамилия 25                  Старший мастер  ночные часы
#
#   2024-01-01 00:00:00  2024-01-02 00:00:00  2024-01-03 00:00:00  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                  11                 11.0                 11.0
# ...

# %%
graf3 = graf3.drop('Должность', axis=1)
graf3.head()
# Вначале удаляем столбец 'mean'
mean = graf3['id']
graf3 = graf3.drop('id', axis=1)

# Затем вставляем его на первое место
graf3.insert(0, 'id', mean)
graf3.head()
# Out:
#    id         фио                       должность     значение  \
# 0   2  Фамилия 14               Начальник участка  явка/неявка
# 1   2  Фамилия 14               Начальник участка  ночные часы
# 2   5  Фамилия 48  Заместитель начальника участка  явка/неявка
# 3   5  Фамилия 48  Заместитель начальника участка  ночные часы
# 4   3  Фамилия 15                  Старший мастер  явка/неявка
#
#   2024-01-01 00:00:00  2024-01-02 00:00:00  2024-01-03 00:00:00  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                  11                 11.0                 11.0
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    2024-01-04 00:00:00  2024-01-05 00:00:00  2024-01-06 00:00:00  ...  \
# 0                  NaN                  NaN                  NaN  ...
# ...

# %% [markdown]
# подгужаем обучения

# %%
graf3.columns[10]
# Out:
# datetime.datetime(2024, 1, 7, 0, 0)

# %%
df = pd.DataFrame()

# Добавляем новый столбец
df['название обучения'] = ['ПБ обучение 1', 'ПБ обучение 2', 'ПБ обучение 6', 'ПБ обучение 7', 'ПБ обучение 8', 'ОТ обучение 1', 'ОТ обучение 2']
df
# Out:
#   название обучения
# 0     ПБ обучение 1
# 1     ПБ обучение 2
# 2     ПБ обучение 6
# 3     ПБ обучение 7
# 4     ПБ обучение 8
# 5     ОТ обучение 1
# 6     ОТ обучение 2

# %%
#for i in range(0,0,2):
#  if graf3.datetime(2024, 3, 16, 0, 0):

# %%
df['дата прохождения'] = [None,None,None,None,None,None,None]
df
# Out:
#   название обучения дата прохождения
# 0     ПБ обучение 1             None
# 1     ПБ обучение 2             None
# 2     ПБ обучение 6             None
# 3     ПБ обучение 7             None
# 4     ПБ обучение 8             None
# 5     ОТ обучение 1             None
# 6     ОТ обучение 2             None

# %%
df['дата прохождения'] = pd.to_datetime(df['дата прохождения'])
df
# Out:
#   название обучения дата прохождения
# 0     ПБ обучение 1              NaT
# 1     ПБ обучение 2              NaT
# 2     ПБ обучение 6              NaT
# 3     ПБ обучение 7              NaT
# 4     ПБ обучение 8              NaT
# 5     ОТ обучение 1              NaT
# 6     ОТ обучение 2              NaT

# %%
# !pip install telebot
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.3/263.3 kB 7.6 MB/s eta 0:00:00
# ...

# %%
'''import telebot

bot = telebot.TeleBot('8082132852:AAHKaXNpbxgEgfJqs8rNGWtcOBunsG3hiBI')

@bot.message_handler(commands=['start'])
def handle_start(message):
    bot.send_message(message.chat.id, "Семен Семенович записан 17.03.2024 на лекцию по ОТ")

bot.polling(none_stop=True) #код бота пробный'''
# Out:
# 'import telebot\n\nbot = telebot.TeleBot(\'8082132852:AAHKaXNpbxgEgfJqs8rNGWtcOBunsG3hiBI\')\n\n@bot.message_handler(commands=[\'start\'])\ndef handle_start(message):\n    bot.send_message(message.chat.id, "Семен Семенович записан 17.03.2024 на лекцию по ОТ")\n\nbot.polling(none_stop=True) #код бота пробный'

# %%
graf3.at[2, "должность"]
#Номер строки, где фио равно иванов  Фамилия 14
# Out:
# 'Заместитель начальника участка'

# %%
#graf3.at[2, targetdate]

# %%
#targetdate = pd.to_datetime('2024-01-06')

# %% [markdown]
# graf3.at[1, pd.to_datetime('2024-01-06')]

# %%
from datetime import date, timedelta
graf3.at[1, pd.to_datetime(date.today())]
# Out:
# nan

# %%
date.today()
# Out:
# datetime.date(2024, 10, 3)

# %%
start_date = date(2024, 3, 16)

# %%
'''n=0
start_date = date(2024, 3, 16)
end_date = date(2024, 3, 20)
for i in range(start_date, end_date):
  if graf3.at[1, pd.to_datetime(i)]==None:
    n+=1
  if n==5:
    print(i)
    break
  else:
    n=0
'''
# Out:
# 'n=0\nstart_date = date(2024, 3, 16)\nend_date = date(2024, 3, 20)\nfor i in range(start_date, end_date):\n  if graf3.at[1, pd.to_datetime(i)]==None:\n    n+=1\n  if n==5:\n    print(i)\n    break\n  else:\n    n=0\n'

# %%
start_date
# Out:
# datetime.date(2024, 3, 16)

# %%
import datetime
n=0
spisok1=[]
     #start_date = datetime.date(2024, 3, 16)
start_date2 = datetime.date(2024, 3, 16)
end_date = datetime.date(2024, 3, 20)

#start_date = datetime.date(2024, 1, 1)
#start_date2 = datetime.date(2024, 1, 1)
#end_date = datetime.date(2024, 1, 6)

# delta time
delta = datetime.timedelta(days=1)
for i in range(0,len(graf3),2):
# iterate over range of dates
  start_date = start_date2

  while (start_date <= end_date):
    #print(pd.to_datetime(start_date), graf3.at[4, pd.to_datetime(start_date)])
    if pd.isna(graf3.at[i, pd.to_datetime(start_date)]):
      n+=1
      #print(n)
    else:
      #break
      n=0
      break
    start_date += delta
    if n==6:
      a=(str(graf3.at[i, "фио"])+ " может пройти обучение с "+str(start_date2) +" по "+ str(end_date)) #по start_date-delta
      spisok1.append(a)
      print(graf3.at[i, "фио"], " может пройти обучение с ",start_date2, " по ", end_date, end="\n") # по start_date-delta
      n=0
      break

#print(start_date, end="\n")
#print(spisok1)
#print(graf3.at[i, "фио"], " должен пройти обучение с ",start_date2, " по ",start_date-delta)
# Out:
# Фамилия 43  может пройти обучение с  2024-03-16  по  2024-03-20
# Фамилия 40  может пройти обучение с  2024-03-16  по  2024-03-20
# Фамилия 51  может пройти обучение с  2024-03-16  по  2024-03-20
# Фамилия 34  может пройти обучение с  2024-03-16  по  2024-03-20

# %%
#a=(str(graf3.at[i, "фио"])+ " должен пройти обучение с "+str(start_date2) +" по "+ str(start_date-delta) +"\n")
#spisok1.append(a)
#spisok1

# %%
spisok1
# Out:
# ['Фамилия 43 может пройти обучение с 2024-03-16 по 2024-03-20',
#  'Фамилия 40 может пройти обучение с 2024-03-16 по 2024-03-20',
#  'Фамилия 51 может пройти обучение с 2024-03-16 по 2024-03-20',
#  'Фамилия 34 может пройти обучение с 2024-03-16 по 2024-03-20']

# %%
#spisok1.clear()

# %%
rr= graf3.at[1, pd.to_datetime(date.today())]
if pd.isna(rr):
  print("y")
# Out:
# y

# %%
if 1==1:
  print("g")
# Out:
# g

# %%
pd.to_datetime(start_date)
# Out:
# Timestamp('2024-03-16 00:00:00')

# %%
obychenia = pd.read_excel('/content/drive/MyDrive/севералмаз/обучения.xlsx')
obychenia
# Out:
# Empty DataFrame
# Columns: [ПБ обучение 2, ПБ обучение 6, ПБ обучение 7, ПБ обучение 8, ОТ обучение 1, ОТ обучение 2, ПБ обучение 1]
# Index: []

# %%
obychenia.insert(0, 'фио', graf3['фио'])
obychenia
# Out:
#             фио ПБ обучение 2 ПБ обучение 6 ПБ обучение 7 ПБ обучение 8  \
# 0    Фамилия 14           NaN           NaN           NaN           NaN
# 1    Фамилия 14           NaN           NaN           NaN           NaN
# 2    Фамилия 48           NaN           NaN           NaN           NaN
# 3    Фамилия 48           NaN           NaN           NaN           NaN
# 4    Фамилия 15           NaN           NaN           NaN           NaN
# ..          ...           ...           ...           ...           ...
# 97   Фамилия 34           NaN           NaN           NaN           NaN
# 98   Фамилия 13           NaN           NaN           NaN           NaN
# 99   Фамилия 13           NaN           NaN           NaN           NaN
# 100  Фамилия 19           NaN           NaN           NaN           NaN
# 101  Фамилия 19           NaN           NaN           NaN           NaN
#
#     ОТ обучение 1 ОТ обучение 2 ПБ обучение 1
# 0             NaN           NaN           NaN
# ...

# %%
obychenia.insert(0, 'id', graf3['id'])
obychenia
# Out:
#      id         фио ПБ обучение 2 ПБ обучение 6 ПБ обучение 7 ПБ обучение 8  \
# 0     2  Фамилия 14           NaN           NaN           NaN           NaN
# 1     2  Фамилия 14           NaN           NaN           NaN           NaN
# 2     5  Фамилия 48           NaN           NaN           NaN           NaN
# 3     5  Фамилия 48           NaN           NaN           NaN           NaN
# 4     3  Фамилия 15           NaN           NaN           NaN           NaN
# ..   ..         ...           ...           ...           ...           ...
# 97    9  Фамилия 34           NaN           NaN           NaN           NaN
# 98    8  Фамилия 13           NaN           NaN           NaN           NaN
# 99    8  Фамилия 13           NaN           NaN           NaN           NaN
# 100   7  Фамилия 19           NaN           NaN           NaN           NaN
# 101   7  Фамилия 19           NaN           NaN           NaN           NaN
#
#     ОТ обучение 1 ОТ обучение 2 ПБ обучение 1
# ...

# %%
proxozobuch = pd.read_excel('/content/drive/MyDrive/севералмаз/Отчёт о прохождении ОТ обучение 1 подразд 1.xlsx')
proxozobuch = proxozobuch[8::]
proxozobuch.head(10)
# Out:
#    Unnamed: 0 Unnamed: 1   Unnamed: 2        Unnamed: 3     Unnamed: 4  \
# 8           1  Фамилия 2      Рабочие  Машинист мельниц  ОТ обучение 1
# 9           2  Фамилия 2      Рабочие  Машинист мельниц  ОТ обучение 1
# 10          3  Фамилия 2      Рабочие  Машинист мельниц  ОТ обучение 1
# 11          4  Фамилия 3  Специалисты         Диспетчер  ОТ обучение 1
# 12          5  Фамилия 3  Специалисты         Диспетчер  ОТ обучение 1
# 13          6  Фамилия 3  Специалисты         Диспетчер  ОТ обучение 1
# 14          7  Фамилия 3  Специалисты         Диспетчер  ОТ обучение 1
# 15          8  Фамилия 3  Специалисты         Диспетчер  ОТ обучение 1
# 16          9  Фамилия 4      Рабочие  Машинист мельниц  ОТ обучение 1
# 17         10  Фамилия 5      Рабочие      Сепараторщик  ОТ обучение 1
#
#                                            Unnamed: 5  Unnamed: 6
# 8             Протокол №29 (машинист мельниц УРиО ОФ)  12.12.2022
# ...

# %%
proxozobuch.rename(columns = {'Unnamed: 1':'фио', 'Unnamed: 6':'дата прохождения'}, inplace = True)
proxozobuch.head(15)
# Out:
#    Unnamed: 0        фио   Unnamed: 2          Unnamed: 3     Unnamed: 4  \
# 8           1  Фамилия 2      Рабочие    Машинист мельниц  ОТ обучение 1
# 9           2  Фамилия 2      Рабочие    Машинист мельниц  ОТ обучение 1
# 10          3  Фамилия 2      Рабочие    Машинист мельниц  ОТ обучение 1
# 11          4  Фамилия 3  Специалисты           Диспетчер  ОТ обучение 1
# 12          5  Фамилия 3  Специалисты           Диспетчер  ОТ обучение 1
# 13          6  Фамилия 3  Специалисты           Диспетчер  ОТ обучение 1
# 14          7  Фамилия 3  Специалисты           Диспетчер  ОТ обучение 1
# 15          8  Фамилия 3  Специалисты           Диспетчер  ОТ обучение 1
# 16          9  Фамилия 4      Рабочие    Машинист мельниц  ОТ обучение 1
# 17         10  Фамилия 5      Рабочие        Сепараторщик  ОТ обучение 1
# 18         11  Фамилия 6      Рабочие  Машинист конвейера  ОТ обучение 1
# 19         12  Фамилия 7      Рабочие        Сепараторщик  ОТ обучение 1
# ...

# %%
import os

# %%
import telebot

bot = telebot.TeleBot('8082132852:AAHKaXNpbxgEgfJqs8rNGWtcOBunsG3hiBI')

@bot.message_handler(commands=['start'])
def handle_start(message):
    bot.send_message(message.chat.id, "Вас приветствует бот \"СЕВЕРОАЛМАЗ-Грань\"")

@bot.message_handler(commands=['staff'])
def handle_start(message):
  bot.send_message(message.chat.id, "Список сотрудников, которые могут пройти обучение в соответствующие даты:")
  for i in range(len(spisok1)):
    bot.send_message(message.chat.id, spisok1[i])

@bot.message_handler(commands=['help'])
def handle_start(message):
    bot.send_message(message.chat.id, "Сейчас вы можете задать вопрос, на который ответят наши специалисты:")
    bot.register_next_step_handler(message, handle_help)

@bot.message_handler(commands=['document_pb'])
def handle_start(message):
    bot.send_document(message.chat.id, open(r'/content/drive/MyDrive/севералмаз/Форма СЗ на обучение по ПБ обучение (1...).docx', 'rb'))


def handle_help(message):
  bot.send_message(message.chat.id, "Вопрос успешно отправлен!")

@bot.message_handler(commands=['document_ot'])
def handle_start(message):
    bot.send_document(message.chat.id, open(r'/content/drive/MyDrive/севералмаз/Форма СЗ на обучение по ОТ ( ОТ обучение 1).docx', 'rb'))


bot.polling(none_stop=True)

# %%
#obychenia= pd.merge(obychenia, proxozobuch["дата прохождения"], on="фио")
#obychenia.head(10)
